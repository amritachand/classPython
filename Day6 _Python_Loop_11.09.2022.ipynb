# %% [markdown]
# # While loop ma Control Space use
#
# s=0
# i=0
# n=int(input("Enter n="))
# while i<n:
#     x=int(input("Enter x= "))
#     s=s+x
#     i=i+1
# print(s)
#
#
# fac=1
# i=1
# n=int(input("Enter n= "))
# while i<=n:
#     fac=fac*i
#     i=i+1
# print(fac)
#
#
# s=str()
# i=0
# n=int(input("Enter n= "))
# while i<n:
#     name=input("Enter name = ")
#     phone=int(input("Enter phone = "))
#     s= s+name+" "+str(phone)+'\n'
#     i=i+1
# print(s)
#
# s=str()
# all_total=0
# i=0
# n=int(input("Enter n= "))
# while i<n:
#     product=input("Enter name= ")
#     price=int(input("Enter product price= "))
#     quantity=int(input("Enter quantity= "))
#     total=price*quantity
#     all_total=all_total+total
#     s=s+product+" "+str(price)+" "+str(quantity)+" "+str(total)+" "+'\n'
#     i=i+1
# print(s)
# print("All total=",all_total)
#
#
# a="Python"
# l=len(a)
# i=0
# while i<l:
#     print(a[i])
#     i=i+1
#
#
#
# a="Hello World I am Python"
# l=len(a)
# i=0
# while i<l:
#     if a[i] !=" ":
#         print(a[i],end ="")
#     i=i+1
#
# # Break and continue in while Loop
#
# a="Hello World I am Python"
# l=len(a)
# i=0
# while i<l:
#     if a[i]==" ":
#         break
#     print(a[i],end="")
#     i=i+1
#
#
# a="Hello World I am Python"
# l=len(a)
# i=0
# while i<l:
#     if a[i]==" ":
#         i=i+1
#         continue
#     print(a[i],end="")
#     i=i+1
#
# # Prime numbers
#
# # prime=2,3,4,5,7,11,13,17
# # composite=4,6,8,9,10,12
# 10
# n=int(input("Enter n= "))
# for i in range(2,n//2):
#     if n%i==0:
#         print(n,"is composite no.")
#         break
# else:
#     print(n,"is prime")
#
# # prime=2,3,4,5,7,11,13,17
# # composite=4,6,8,9,10,12
#
# n=int(input("Enter n= "))
# if n>=2:
#     for i in range(2,n//2):
#         if n%i==0:
#             print(n,"is composite no.")
#             break
#     else:
#         print(n,"is prime")
# else:
#     print("The value of n should be greater or equal to 2")

# %% [markdown]
# # Loop (UP)
